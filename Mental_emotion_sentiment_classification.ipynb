# %%
import pandas as pd

brainwave_df = pd.read_csv('C:\Users\agurm\Downloads\emotions.csv')
brainwave_df.df()
# Out:
#   File "<ipython-input-1-2e1ee487b6ac>", line 3
#     brainwave_df = pd.read_csv('C:\Users\agurm\Downloads\emotions.csv')
#                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions.csv')
brainwave_df.df()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-5240417ce848> in <module>
#       1 import pandas as pd
#       2
# ----> 3 brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions.csv')
#       4 brainwave_df.df()
#
# ...

# %%
import pandas as pd

# %%
brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-eb344fffd542> in <module>
# ----> 1 brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
import OS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-4447e580a96f> in <module>
# ----> 1 import OS
#
# ModuleNotFoundError: No module named 'OS'

# %%
import os

# %%
brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-eb344fffd542> in <module>
# ----> 1 brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions/emotions.csv', index_col=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-6a0eb0e513ff> in <module>
# ----> 1 brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions/emotions.csv', index_col=False)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
brainwave_df = pd.read_csv('C:/Users/agurm/Downloads/emotions/emotions.csv', index_col=False)

# %%
brainwave_df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
sns.countplot(x=brainwave_df.label, color = 'mediumseagreen')
plt.title('Emotional sentiment class distribution', fontsize=16)
plt.ylabel('Class counts', fontsize = 16)
plt.xlabel('Class label', fontsize=16)
plt.xticks(rotation='vertical');

# %%
label_df = brainwave_df['label']
brainwave_df.drop('label', axis = 1, inplace=True)
brainwave_df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_740_b  fft_741_b  fft_742_b  \
# 0      -15.70        2.06        3.15  ...       74.3       23.5       20.3
# 1        2.88        3.83       -4.82  ...      130.0      -23.3      -21.8
# 2       90.20       89.90        2.03  ...     -534.0      462.0     -233.0
# 3        8.82        2.30       -1.97  ...     -183.0      299.0     -243.0
# 4        3.06       41.40        5.52  ...      114.0       12.0       38.1
#
# ...

# %%
from sklearn.pipeline import pipleline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
plt_random_forest = pipeline(steps=[('random_forest', RandomForestClassifier())])
score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for RandomForest :', score.mean())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-91f2f8772b1b> in <module>
# ----> 1 from sklearn.pipeline import pipleline
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 from sklearn.model_selection import cross_val_score, train_test_split
#       4 plt_random_forest = pipeline(steps=[('random_forest', RandomForestClassifier())])
#       5 score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
#
# ImportError: cannot import name 'pipleline' from 'sklearn.pipeline' (C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\pipeline.py)

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
plt_random_forest = pipeline(steps=[('random_forest', RandomForestClassifier())])
score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for RandomForest :', score.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9040d3b2e667> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 from sklearn.model_selection import cross_val_score, train_test_split
# ----> 3 plt_random_forest = pipeline(steps=[('random_forest', RandomForestClassifier())])
#       4 score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
#       5 print('Accuracy for RandomForest :', score.mean())
#
# NameError: name 'pipeline' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
plt_random_forest = Pipeline(steps=[('random_forest', RandomForestClassifier())])
score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for RandomForest :', score.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-ef4935992097> in <module>
#       2 from sklearn.model_selection import cross_val_score, train_test_split
#       3 plt_random_forest = Pipeline(steps=[('random_forest', RandomForestClassifier())])
# ----> 4 score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
#       5 print('Accuracy for RandomForest :', score.mean())
#
# NameError: name 'pl_random_forest' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split

# %%
plt_random_forest = Pipeline(steps=[('random_forest', RandomForestClassifier())])

# %%
score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for RandomForest :', score.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-0a4a0baf1e4a> in <module>
# ----> 1 score = cross_val_score(pl_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
#       2 print('Accuracy for RandomForest :', score.mean())
#
# NameError: name 'pl_random_forest' is not defined

# %%
score = cross_val_score(plt_random_forest, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for RandomForest :', score.mean())
# Out:
# Accuracy for RandomForest : 0.9868720108814883

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
pl_log_log = Pipeline(steps=[('scaler', StandardScaler()),
                            ('log_reg', LogisticRegression(multi_class='multinomial', solver ='saga', max_iter=200))])
score = cross_val_score(pl_log_log, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for RandomForest :', score.mean())
# Out:
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_df = scaler.fit_transform(brainwave_df)
pca = PCA(n_components = 20)
pca_vectors = PCA.fit_transform(scaled_df)
for index, var in enumerate(PCA.explained_variance_ratio):
    print("Explained Variance ratio by Principal Component", (index+1), " : ", var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-6deaab22869d> in <module>
#       5 scaled_df = scaler.fit_transform(brainwave_df)
#       6 pca = PCA(n_components = 20)
# ----> 7 pca_vectors = PCA.fit_transform(scaled_df)
#       8 for index, var in enumerate(PCA.explained_variance_ratio):
#       9     print("Explained Variance ratio by Principal Component", (index+1), " : ", var)
#
# TypeError: fit_transform() missing 1 required positional argument: 'X'

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_df = scaler.fit_transform(brainwave_df)

# %%
pca = PCA(n_components = 20)

# %%
pca_vectors = pca.fit_transform(scaled_df)

# %%
for index, var in enumerate(pca.explained_variance_ratio_):
    print("Explained Variance ratio by Principal Component", (index+1), " : ", var)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a024bfbfd11d> in <module>
# ----> 1 for index, var in enumerate(pca.explained_variance_ratio):
#       2     print("Explained Variance ratio by Principal Component", (index+1), " : ", var)
#
# AttributeError: 'PCA' object has no attribute 'explained_variance_ratio'

# %%
for index, var in enumerate(pca.explained_variance_ratio_):
    print("Explained Variance ratio by Principal Component", (index+1), " : ", var)
# Out:
# Explained Variance ratio by Principal Component 1  :  0.3677256411753881
# Explained Variance ratio by Principal Component 2  :  0.09553894257232576
# Explained Variance ratio by Principal Component 3  :  0.08436069000482446
# Explained Variance ratio by Principal Component 4  :  0.06085665181970145
# Explained Variance ratio by Principal Component 5  :  0.04745373292625158
# Explained Variance ratio by Principal Component 6  :  0.030823052518471294
# Explained Variance ratio by Principal Component 7  :  0.024721620860921428
# Explained Variance ratio by Principal Component 8  :  0.013753055070717168
# Explained Variance ratio by Principal Component 9  :  0.012408702721157542
# Explained Variance ratio by Principal Component 10  :  0.012103653571896187
# Explained Variance ratio by Principal Component 11  :  0.009557100563252971
# Explained Variance ratio by Principal Component 12  :  0.009164311017281835
# Explained Variance ratio by Principal Component 13  :  0.008740057291450212
# ...

# %%
plt.figure(figsize=(25, 8))
sns.scatterplot(x=pca_vectors[:, 0], y=pca_vectors[:, 1], hue=label_df)
plt.title('Principal Components vs Class distribution', fontsize=16)
plt.ylable('Principal Component 2', fontsize=16)
plt.xlabel('Principal Component 1', fontsize=16)
plt.xticks(rotation='vertical');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-560a74bf0d9c> in <module>
#       2 sns.scatterplot(x=pca_vectors[:, 0], y=pca_vectors[:, 1], hue=label_df)
#       3 plt.title('Principal Components vs Class distribution', fontsize=16)
# ----> 4 plt.ylable('Principal Component 2', fontsize=16)
#       5 plt.xlabel('Principal Component 1', fontsize=16)
#       6 plt.xticks(rotation='vertical');
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
plt.figure(figsize=(25, 8))
sns.scatterplot(x=pca_vectors[:, 0], y=pca_vectors[:, 1], hue=label_df)
plt.title('Principal Components vs Class distribution', fontsize=16)
plt.ylabel('Principal Component 2', fontsize=16)
plt.xlabel('Principal Component 1', fontsize=16)
plt.xticks(rotation='vertical');

# %%
from sklearn.linear_model import LogisticRegression
pl_log_reg_pca = Pipeline(steps=[('scaler', StandardScaler()),
                                ('pca', PCA(n_components = 10)),
                                ('log_reg', LogisticRegression(multi_class='multinomial', solver='sage', max_iter=200))])
scores = cross_val_score(pl_log_reg_pca, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for Logistic Regression with 2 Principal Components: ', scores.mean())
# Out:
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
from sklearn.linear_model import LogisticRegression
pl_log_reg_pca = Pipeline(steps=[('scaler', StandardScaler()),
                                ('pca', PCA(n_components = 10)),
                                ('log_reg', LogisticRegression(multi_class='multinomial', solver='sage', max_iter=200))])
scores = cross_val_score(pl_log_reg_pca, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for Logistic Regression with 10 Principal Components: ', scores.mean())
# Out:
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pl_log_reg_pca = Pipeline(steps=[('scaler', StandardScaler()),
                                ('pca', PCA(n_components = 10)),
                                ('log_reg', LogisticRegression(multi_class='multinomial', solver='sage', max_iter=200))])
scores = cross_val_score(pl_log_reg_pca, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for Logistic Regression with 10 Principal Components: ', scores.mean())
# Out:
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pl_log_reg_pca = Pipeline(steps=[('scaler', StandardScaler()),
                                ('pca', PCA(n_components = 10)),
                                ('log_reg', LogisticRegression(multi_class='multinomial', solver='sage', max_iter=200))])

# %%
from sklearn.neural_network import MLPClassifier

pl_mlp=Pipeline(steps=[('scaler' , StandardScaler()),
               ('mlp_ann', MLPClassifier(hidden_layer_sizes=(1275, 637)))])
scores = cross_val_score(pl_mlp, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for ANN : ', scores.mean())
# Out:
# Accuracy for ANN :  0.9728006669299283

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

pl_svm = Pipeline(steps=[('scaler', StandardScaler()),
                        ('pl_svm', LinearSVC())])
scores = cross_val_score(pl_svm, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for Linear SVM : ', scores.mean())
# Out:
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# ...

# %%
import xgboost as xgb

pl_xgb = Pipeline(steps=[('xgboost', xgb.XGBClassifier(objective='multi:softmax'))])
scores = cross_val_score(pl_xgb, brainwave_df, label_df, cv=10)
print('Accuracy for XGBoost Classifier : ', scores.mean())
# Out:
# Accuracy for XGBoost Classifier :  0.9939032951603701

# %%
# %%time
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pl_log_reg_pca = Pipeline(steps=[('scaler', StandardScaler()),
                                ('pca', PCA(n_components = 10)),
                                ('log_reg', LogisticRegression(multi_class='multinomial', solver='sage', max_iter=200))])
scores = cross_val_score(pl_log_reg_pca, brainwave_df, label_df, cv=10, scoring='accuracy')
print('Accuracy for Logistic Regression with 10 Principal Components: ', scores.mean())
# Out:
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got sage.
#
#   FitFailedWarning)
# C:\Users\agurm\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...
